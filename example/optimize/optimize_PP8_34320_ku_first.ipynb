# %% [markdown]
# # Optimize incident flux

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from scipy.optimize import minimize
import festim as F

from festim_permeation_fit.optimize import optimize_flux_without_output
from festim_permeation_fit.piecewise import compress_piecewise

print(F.__version__)
# Out:
# 1.4.1.post1

# %%
shot = 34320
date = 170112
filename = '34320_PDP8_calibrated_f1--2_f2-1.0_winsma-30_winsg1-71_winsg2-7_w2-range310_s5.txt'

# 05_calc_ku/170112/ku_calculator_PP8_34319.ipynb, before kink
ku = 2.5e-31
kd = 5.0e-31

# 04_check_concentration
initial_perm = 8.54e+14
initial_solute = 4.13e+22

# Settings
dt = 2 # s
calc_time = 300 # s
discharge_start = 1.5 # s
inc_amp = 1e16
ver = f"PP8_{shot}_ku-{ku}"

# %% [markdown]
# ## Plot of Permeation Data
#
# - xx, yy
#     - Full shot data
# - ax, ay
#     - Analysis range (including initial flux consideration)
# - bx, by
#     - Discharge duration (FESTIM calculation range)

# %%
df = pd.read_csv(f'../../data/calibrated/{date}/{filename}', sep=r'\s+', header=None)

num_cols = df.select_dtypes('number').columns

x = df[num_cols[0]]
y = df[num_cols[1]]

xx = np.linspace(x.min(),x.max(),len(x))
fy = interp1d(x,y)
yy = fy(xx)

# %%
cut = xx[-1] - 20

ind_a = np.where(xx < cut)
ax, ay = (xx[ind_a], yy[ind_a]+initial_perm)

ind_b = np.where((ax < calc_time))
bx, by = (ax[ind_b], ay[ind_b])

# plt.plot(xx, yy)
plt.plot(ax, ay,)
plt.plot(bx, by,)

plt.xlabel('time [s]')
plt.ylabel(r'Permeation flux [$\mathrm{H} \cdot \mathrm{m}^{-2} \mathrm{s}^{-1}$]')
plt.show()

# %% [markdown]
# ## FESTIM Settings

# %% [markdown]
# Every FESTIM model is represented by a `Simulation` object. Here, we give it the name `my_model`

# %%
my_model = F.Simulation()

# %% [markdown]
# ### Mesh
#
# FESTIM simulations need a mesh. FESTIM provides support for simple 1D meshes.

# %%
my_model.mesh = F.MeshFromVertices(
    vertices=np.linspace(0, 2e-5, num=301)
)

# %% [markdown]
# ### Diffusion Coefficient
#
# `Material` objects hold the materials properties like diffusivity and solubility.
#
# Here we only need the diffusivity defined as an Arrhenius law:
#
# $$
#     D = D_0 \exp{(-E_D/k_B T)}
# $$
#
# where $k_B$ is the Boltzmann constant in eV/K and $T$ is the temperature in K. From this, the pre-exponential coefficient, $D_0$ in m<sup>2</sup>/s, and the diffusion actiavtion energy, $E_D$ in eV are needed.

# %%
my_model.materials = F.Material(id=1, D_0=2.9e-8, E_D=0.048) # m^2/s

# %% [markdown]
# ### Membrane Temperature

# %%
my_model.T = 573 # K

# %% [markdown]
# ### Boundary conditions & source
#
# ``surfaces`` is a list of surfaces ids (in 1D, `1` is left and `2` is right).
#
# - Upstream Surface (Plasma-Facing Side)
#   - Hydrogen Atoms from Plasma (FluxBC)
#   - Hydrogen Molecules Released via Recombination (RecombinationFlux)
# - Downstream Surface (Vacuum Side)
#   - Hydrogen Molecules Released via Recombination (RecombinationFlux)

# %%
# Defined in optimize_flux() (src/festim_permeation_fit/optimize.py)

# my_model.boundary_conditions = [
#     F.FluxBC(surfaces=1, value=flux_expr, field="solute"),
#     F.RecombinationFlux(surfaces=1, Kr_0=ku, E_Kr=0, order=2),
#     F.RecombinationFlux(surfaces=2, Kr_0=kd, E_Kr=0, order=2),
# ]

# %% [markdown]
# ### Settings
#
# With `Settings` we set the main solver parameters.
# - `absolute_tolerance`: the absolute tolerance of the Newton solver.
# - `relative_tolerance`: the relative tolerance of the Newton solver.
# - `final_time`: since we want to solve a transient problem, we need to set the final time.

# %%
my_model.settings = F.Settings(
    absolute_tolerance=1e10,
    relative_tolerance=1e-10,
    final_time=int((ax[-1] // dt) * dt)  # s
)

# %% [markdown]
# ### Initial Concentration

# %%
my_model.initial_conditions = [
    F.InitialCondition(value=initial_solute, field="solute")
]

# %% [markdown]
# ### Exports

# %%
derived_quantities = F.DerivedQuantities(
    [F.HydrogenFlux(surface=2)],  # Permeation Flux on the Vacuum Side
    show_units=True,
)

my_model.exports = [derived_quantities]

# %% [markdown]
# ### Stepsize
#
# Since we are solving a transient problem, we need to set a ``Stepsize``.

# %%
my_model.dt = F.Stepsize(initial_value=dt)

# %% [markdown]
# ## Optimization

# %% [markdown]
# ### Settings

# %%
Nt = int(ax[-1] // dt)
calc_point = int(calc_time // dt)
fixed_point = Nt - calc_point

sample_time = np.arange(start=dt, stop=bx[-1]+dt, step=dt)
selected_indices = [np.abs(bx - t).argmin() for t in sample_time]

bx_arg = bx[selected_indices]
by_arg = by[selected_indices]

# %%
config = {
    'model': my_model,
    'dq': derived_quantities,
    'Nt': Nt,
    'inc_amp': inc_amp,
    'dt': dt,
    'ku': ku,
    'kd': kd
}

# %% [markdown]
# ### Optimization loop

# %%
G_opt = [0] * int(discharge_start/dt)

# --- Optimization loop ---
for i in range(len(G_opt), calc_point) :
    print(f"Optimizing timestep {i+1}/{calc_point}")

    res = minimize(
        optimize_flux_without_output,
        x0=[1.0],  # initial Values
        bounds=[(0, None)],
        args=(G_opt, i, by_arg, config),
        method="L-BFGS-B",
        options={
            "eps": 1e-2,
            "maxiter": 20000,
            "maxfun": 20000,
        }
    )

    G_opt.append(res.x[0])


print("Optimization results:", G_opt)

G_opt += [0] * fixed_point
G_opt = np.array(G_opt)
# Out:
# Optimizing timestep 1/150
# Optimizing timestep 2/150
# Optimizing timestep 3/150
# Optimizing timestep 4/150
# Optimizing timestep 5/150
# Optimizing timestep 6/150
# Optimizing timestep 7/150
# Optimizing timestep 8/150
# Optimizing timestep 9/150
# Optimizing timestep 10/150
# Optimizing timestep 11/150
# Optimizing timestep 12/150
# Optimizing timestep 13/150
# Optimizing timestep 14/150
# Optimizing timestep 15/150
# Optimizing timestep 16/150
# Optimizing timestep 17/150
# Optimizing timestep 18/150
# Optimizing timestep 19/150
# Optimizing timestep 20/150
# Optimizing timestep 21/150
# Optimizing timestep 22/150
# Optimizing timestep 23/150
# Optimizing timestep 24/150
# Optimizing timestep 25/150
# Optimizing timestep 26/150
# Optimizing timestep 27/150
# Optimizing timestep 28/150
# Optimizing timestep 29/150
# Optimizing timestep 30/150
# Optimizing timestep 31/150
# Optimizing timestep 32/150
# Optimizing timestep 33/150
# Optimizing timestep 34/150
# Optimizing timestep 35/150
# Optimizing timestep 36/150
# Optimizing timestep 37/150
# Optimizing timestep 38/150
# Optimizing timestep 39/150
# Optimizing timestep 40/150
# Optimizing timestep 41/150
# Optimizing timestep 42/150
# Optimizing timestep 43/150
# Optimizing timestep 44/150
# Optimizing timestep 45/150
# Optimizing timestep 46/150
# Optimizing timestep 47/150
# Optimizing timestep 48/150
# Optimizing timestep 49/150
# Optimizing timestep 50/150
# Optimizing timestep 51/150
# Optimizing timestep 52/150
# Optimizing timestep 53/150
# Optimizing timestep 54/150
# Optimizing timestep 55/150
# Optimizing timestep 56/150
# Optimizing timestep 57/150
# Optimizing timestep 58/150
# Optimizing timestep 59/150
# Optimizing timestep 60/150
# Optimizing timestep 61/150
# Optimizing timestep 62/150
# Optimizing timestep 63/150
# Optimizing timestep 64/150
# Optimizing timestep 65/150
# Optimizing timestep 66/150
# Optimizing timestep 67/150
# Optimizing timestep 68/150
# Optimizing timestep 69/150
# Optimizing timestep 70/150
# Optimizing timestep 71/150
# Optimizing timestep 72/150
# Optimizing timestep 73/150
# Optimizing timestep 74/150
# Optimizing timestep 75/150
# Optimizing timestep 76/150
# Optimizing timestep 77/150
# Optimizing timestep 78/150
# Optimizing timestep 79/150
# Optimizing timestep 80/150
# Optimizing timestep 81/150
# Optimizing timestep 82/150
# Optimizing timestep 83/150
# Optimizing timestep 84/150
# Optimizing timestep 85/150
# Optimizing timestep 86/150
# Optimizing timestep 87/150
# Optimizing timestep 88/150
# Optimizing timestep 89/150
# Optimizing timestep 90/150
# Optimizing timestep 91/150
# Optimizing timestep 92/150
# Optimizing timestep 93/150
# Optimizing timestep 94/150
# Optimizing timestep 95/150
# Optimizing timestep 96/150
# Optimizing timestep 97/150
# Optimizing timestep 98/150
# Optimizing timestep 99/150
# Optimizing timestep 100/150
# Optimizing timestep 101/150
# Optimizing timestep 102/150
# Optimizing timestep 103/150
# Optimizing timestep 104/150
# Optimizing timestep 105/150
# Optimizing timestep 106/150
# Optimizing timestep 107/150
# Optimizing timestep 108/150
# Optimizing timestep 109/150
# Optimizing timestep 110/150
# Optimizing timestep 111/150
# Optimizing timestep 112/150
# Optimizing timestep 113/150
# Optimizing timestep 114/150
# Optimizing timestep 115/150
# Optimizing timestep 116/150
# Optimizing timestep 117/150
# Optimizing timestep 118/150
# Optimizing timestep 119/150
# Optimizing timestep 120/150
# Optimizing timestep 121/150
# Optimizing timestep 122/150
# Optimizing timestep 123/150
# Optimizing timestep 124/150
# Optimizing timestep 125/150
# Optimizing timestep 126/150
# Optimizing timestep 127/150
# Optimizing timestep 128/150
# Optimizing timestep 129/150
# Optimizing timestep 130/150
# Optimizing timestep 131/150
# Optimizing timestep 132/150
# Optimizing timestep 133/150
# Optimizing timestep 134/150
# Optimizing timestep 135/150
# Optimizing timestep 136/150
# Optimizing timestep 137/150
# Optimizing timestep 138/150
# Optimizing timestep 139/150
# Optimizing timestep 140/150
# Optimizing timestep 141/150
# Optimizing timestep 142/150
# Optimizing timestep 143/150
# Optimizing timestep 144/150
# Optimizing timestep 145/150
# Optimizing timestep 146/150
# Optimizing timestep 147/150
# Optimizing timestep 148/150
# Optimizing timestep 149/150
# Optimizing timestep 150/150
# Optimization results: [np.float64(0.7822155102827597), np.float64(1.525459463287676), np.float64(1.714422555101383), np.float64(2.107625187396174), np.float64(2.0574347201311984), np.float64(2.0636266606895175), np.float64(2.281210292334158), np.float64(2.0500508738318786), np.float64(2.126212683036796), np.float64(1.8498516945909105), np.float64(1.72036121787835), np.float64(1.8018095892960793), np.float64(1.59317818198497), np.float64(1.6482199314157486), np.float64(1.4595532551845118), np.float64(1.3852615452448565), np.float64(1.4701493637316223), np.float64(1.3211577981267348), np.float64(1.3903275563266067), np.float64(1.2579447832381454), np.float64(1.216642777561304), np.float64(1.304214666209038), np.float64(1.197259666300191), np.float64(1.273960522637027), np.float64(1.177418125439483), np.float64(1.1576058377384513), np.float64(1.2542129465373337), np.float64(1.1708250777898932), np.float64(1.2519975939799117), np.float64(1.1640264518929213), np.float64(1.1442016695340016), np.float64(1.225651337039038), np.float64(1.1377102403936312), np.float64(1.1991943647135073), np.float64(1.1096022266813925), np.float64(1.0819574238761884), np.float64(1.1404416200896497), np.float64(1.062318937805014), np.float64(1.1128991804401824), np.float64(1.0431530578720587), np.float64(1.0289887533509232), np.float64(1.0932317556132727), np.float64(1.0374766705344483), np.float64(1.0997933982460084), np.float64(1.0488232948072775), np.float64(1.0478433421444049), np.float64(1.121880969867223), np.float64(1.0723151435991396), np.float64(1.1375787079195632), np.float64(1.0845894784909318), np.float64(1.080244899079952), np.float64(1.150759228520534), np.float64(1.0968766432777433), np.float64(1.1574215754041175), np.float64(1.1017683845926394), np.float64(1.0943021116685825), np.float64(1.1578190855622021), np.float64(1.1032599256171698), np.float64(1.1560380155503978), np.float64(1.100659862403596), np.float64(1.0904008290513574), np.float64(1.144549634870734), np.float64(1.0909992432951292), np.float64(1.1352417314059495), np.float64(1.083418107762479), np.float64(1.07329564960794), np.float64(1.1231470997881607), np.float64(1.0760101106468807), np.float64(1.1195547613489054), np.float64(1.074780961217828), np.float64(1.0688509076930466), np.float64(1.1173543120716314), np.float64(1.0771648211533071), np.float64(1.1204695142144956), np.float64(1.082043081894128), np.float64(1.0792354210154087), np.float64(1.129197277047502), np.float64(1.09295157301898), np.float64(1.1402134773810024), np.float64(1.1037709606011314), np.float64(1.1048656035846833), np.float64(1.1577657807903856), np.float64(1.1227180213214145), np.float64(1.170031541561186), np.float64(1.1322218817082743), np.float64(1.1312887391886595), np.float64(1.180324305844112), np.float64(1.1420275236824755), np.float64(1.1854437059719756), np.float64(1.145444094849817), np.float64(1.1402057219748745), np.float64(1.1838579971888932), np.float64(1.1440354535645927), np.float64(1.1792790887088882), np.float64(1.1406059984352657), np.float64(1.132230056346237), np.float64(1.16658921693859), np.float64(1.1292175461784801), np.float64(1.1578120867978607), np.float64(1.1167831078908108), np.float64(1.1090438020033035), np.float64(1.1431762984411522), np.float64(1.1165700073109392), np.float64(1.1502782952138368), np.float64(1.129420638438474), np.float64(1.1349300447894757), np.float64(1.1844039827590127), np.float64(1.1670936250215085), np.float64(1.221977021894501), np.float64(1.1945761302146647), np.float64(1.1920141206710169), np.float64(1.2231833571741335), np.float64(1.177411430310045), np.float64(1.1904598046105375), np.float64(1.151230291050526), np.float64(1.143138797161203), np.float64(1.1709761361033177), np.float64(1.149794867060743), np.float64(1.181778433976678), np.float64(1.1601601745176484), np.float64(1.1604630623516465), np.float64(1.1942249372761489), np.float64(1.1703926442820087), np.float64(1.2011746252803612), np.float64(1.1772373131022327), np.float64(1.174827 ...

# %%
incident_opt_piecewise = compress_piecewise(G_opt*inc_amp, F.t, dt)

my_model.boundary_conditions = [
    F.FluxBC(surfaces=1, value=incident_opt_piecewise, field="solute"),
    F.RecombinationFlux(surfaces=1, Kr_0=ku, E_Kr=0, order=2),
    F.RecombinationFlux(surfaces=2, Kr_0=kd, E_Kr=0, order=2),
]

my_model.initialise()
my_model.run()
# Out:
# Defining initial values
# Defining variational problem
# Defining source terms
# Defining boundary conditions
# Time stepping...
# 100.0 %        1.1e+03 s    Elapsed time so far: 0.8 s

# %% [markdown]
# ## Results

# %% [markdown]
# ### Plot of fitting results

# %%
time = np.array(derived_quantities.t)
permeation_opt = np.abs(derived_quantities.filter(surfaces=2).data)
incident_opt = np.array(G_opt*inc_amp)

# %%
fig, ax1 = plt.subplots(figsize=(9, 6))
ax2 = ax1.twinx()

ax1.axvline(x=calc_time, color='green', linestyle='--', label=f'x={calc_time}')
ax1.plot(ax, ay, 'o-', color='black')
ax1.plot(time, permeation_opt, 'o-', color='tab:blue')
ax2.plot(time, incident_opt, 'o-', color='tab:orange')

ax1.set_xlabel('Time [s]', fontsize=18)

ax1.set_ylabel(r'Permeation flux [$\mathrm{H} \cdot \mathrm{m}^{-2} \mathrm{s}^{-1}$]', color='tab:blue', fontsize=18)
ax2.set_ylabel(r'Incident flux [$\mathrm{H} \cdot \mathrm{m}^{-2} \mathrm{s}^{-1}$]', color='tab:orange', fontsize=18)

ax1.tick_params(axis='x', labelsize=14)
ax1.tick_params(axis='y', labelsize=14)
ax2.tick_params(axis='y', labelsize=14)

ax1.set_xlim(left=0,right=calc_time+10)
ax1.set_ylim(bottom=0)
ax2.set_ylim(bottom=0)
plt.show()

# %% [markdown]
# ### Output fitting results

# %%
time_csv = pd.Series(time)
incident_csv = pd.Series(incident_opt)
permeation_csv = pd.Series(permeation_opt)

filename = f'../../data/optimized/{date}/opt_{ver}.csv'

df = pd.DataFrame({'t(s)': time_csv, 'incident': incident_csv, 'permeation': permeation_csv})

df.to_csv(filename, index=False)

print(f"Saved data to '{filename}'")
# Out:
# Saved data to '../../data/optimized/170112/opt_PP8_34320_ku-2.5e-31.csv'
